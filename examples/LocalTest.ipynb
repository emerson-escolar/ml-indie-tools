# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../src/ml_indie_tools')  # Point to local module source

# %%
from env_tools import MLEnv

# %%
ml=MLEnv(platform='jax', accelerator='gpu')
ml.describe()
# Out:
# 'OS: Darwin, Python: 3.9.9 (Conda), Jupyter Notebook (no-ml-platform) '

# %%
import logging
logging.basicConfig(encoding='utf-8', level=logging.INFO)
from Gutenberg_Dataset import Gutenberg_Dataset

# %%
# simply remove root_url parameter, if no local Gutenberg mirror is available, files are then downloaded on-demand
gd=Gutenberg_Dataset(root_url='/Volumes/ExFat3TB/Corpora/Gutenberg')
gd.load_index()
# Out:
# INFO:GutenbergLib:Gutenberg index read from local mirror: /Volumes/ExFat3TB/Corpora/Gutenberg/GUTINDEX.ALL

# %%
gd.search?
# Out:
# Signature: gd.search(search_dict)
# Docstring:
# Search for book record with key specific key values
# For a list of valid keys, use `get_record_keys()`
# Standard keys are: `ebook_id`, `author`, `language`, `title`
#
# *Note:* :func:`~Gutenberg_Dataset.Gutenberg_Dataset.load_index` needs to be called once before this function can be used.
#
# Example: `search({"title": ["philosoph","phenomen","physic","hermeneu","logic"], "language":"english"})`
# Find all books whose titles contain at least one of the keywords, language english. Search keys can either be
# search for a single keyword (e.g. english), or an array of keywords.
#
# :returns: list of records
# File:      ~/gith/domschl/ml-indie-tools/src/ml_indie_tools/Gutenberg_Dataset.py
# Type:      method

# %%
sl=gd.search({'title': ['physi', 'philo', 'hermen', 'logi']})

# %%
sl2=gd.insert_book_texts(sl)
# Out:
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/7/0/1/67017/67017-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/6/9/5/66955/66955-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/6/8/6/66869/66869-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/6/7/0/66703/66703-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/6/4/0/66406/66406-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/6/3/6/66369/66369-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/8/6/65867/65867-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/7/0/65708/65708-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/7/0/65704/65704-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/4/7/65478/65478-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/3/5/65359/65359-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/2/9/65295/65295-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/2/9/65293/65293-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/2/7/65274/65274-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/2/6/65260/65260-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/1/7/65171/65171-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/1/4/65145/65145-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/0/9/65097/65097-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/4/8/4/64842/64842-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/4/6/1/64610/64610-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/4/4/5/64451/64451-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/4/4/4/64441/64441-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/4/3/7/64371/64371-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/4/0/9/64097/64097-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/3/9/5/63958/63958-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/3/5/9/63598/63598-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/3/5/4/63548/63548-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/3/3/9/63396/63396-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/3/3/6/63366/63366-8.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/3/3/2/63322/63322-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/3/2/7/63274/63274-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/2/9/5/62958/62958-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/2/8/8/62886/62886-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/2/7/2/62726/62726-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/2/6/9/62693/62693-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/2/6/6/62663/62663-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/2/6/6/62660/62660-8.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/2/5/5/62557/62557-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/2/0/6/62067/62067-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/1/8/7/61873/61873-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/1/6/6/61663/61663-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/1/6/5/61652/61652-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/1/6/5/61651/61651-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/1/5/1/61515/61515-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/1/4/9/61493/61493-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/1/4/1/61412/61412.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/1/2/4/61249/61249-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/0/9/8/60989/60989-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/0/9/3/60937/60937-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/0/7/7/60773/60773-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/0/5/7/60574/60574-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/0/2/3/60234/60234-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/0/2/1/60212/60212-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/0/2/0/60201/60201-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/0/0/6/60068/60068-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/0/0/0/60009/60009-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/9/8/3/59838/59838-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/9/8/3/59836/59836-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/9/7/8/59780/59780-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/9/5/9/59590/59590.txt
# WARNING:GutenbergLib:End-text is taking more than half of the book!
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/9/3/5/59355/59355-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/9/2/6/59268/59268-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/9/1/0/59108/59108-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/9/0/0/59006/59006-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/8/9/5/58951/58951-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/8/9/2/58927/58927-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/8/8/8/58881/58881-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/8/7/0/58704/58704-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/8/6/1/58612/58612-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/8/2/2/58224/58224-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/8/2/1/58210/58210-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/8/1/6/58169/58169-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/7
txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/9/1/5/9159/9159-8.txt
# WARNING:GutenbergLib:Failed to download [('are-pdf.pdf', 'bin')], skipping book.
# WARNING:GutenbergLib:Download of book are, [NOTE: Unfortunately numbers 9116 through 9142 are missing, and not expected to ever be recovered. They were computer-generated audio eBooks. The text sources for the items are still available. Project Gutenberg apologizes for the loss of these files.]: invalid format!
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/8/2/0/8207/8207.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/8/1/0/8103/8103-8.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/7/9/7/7976/7976-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/7/5/8/7584/7584.txt
# WARNING:GutenbergLib:End-text is taking more than half of the book!
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/9/8/6986/6986-8.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/8/3/6834/6834-8.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/7/9/6799/6799.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/7/2/6729/6729-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/6/9/6698/6698-8.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/6/6/6660/6660.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/5/6/6560/6560-8.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/4/8/6481/6481.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/3/3/6335/6335.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/1/2/6123/6123-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/9/5/5958/5958.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/8/9/5899/5899.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/8/4/5849/5849.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/8/2/5827/5827.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/7/4/5740/5740-pdf.pdf
# ERROR:GutenbergLib:Ebook 5740.pdf is only available in PDF format, this is not supported.
# WARNING:GutenbergLib:Download of book 5740, Tractatus Logico-Philosophicus: invalid format!
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/7/1/5717/5717.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/7/0/5704/5704.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/6/8/5684/5684.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/6/8/5682/5682.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/6/3/5637/5637.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/6/3/5630/5630.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/4/3/5434/5434.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/3/2/5329/5329.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/5/2/4/5246/5246-0.txt
# WARNING:GutenbergLib:Failed to download [('4935-pdf.pdf', 'bin')], skipping book.
# WARNING:GutenbergLib:Download of book 4935, Pathologie Verbale, ou Lesions de certains mots dans le cours de l'usage: invalid format!
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/4/7/6/4763/4763.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/4/7/5/4754/4754.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/4/7/2/4724/4724.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/4/3/9/4391/4391.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/4/3/6/4368/4368.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/4/3/5/4350/4350.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/3/9/9/3999/3999-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/3/9/9/3998/3998.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/3/9/9/3997/3997.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/3/9/9/3996/3996.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/3/6/2/3620/3620-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/2/9/3/2936/2936.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/2/6/3/2634/2634.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/1/3/4/1347/1347.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/9/9/992/992-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/9/9/991/991-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/9/9/990/990.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/9/8/989/989-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/8/6/868/868.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/8/6/862/862-0.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/8/0/806/806.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/7/2/726/726.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/6/2/626/626.txt
# INFO:GutenbergLib:Book read from local mirror at /Volumes/ExFat3TB/Corpora/Gutenberg/4/4/444/444.txt

# %%
from Text_Dataset import *

# %%
tl = Text_Dataset(sl2)
# Out:
# ERROR:Datasets:Missing attribute(s) ['author'] in text[4], skipping
# ERROR:Datasets:Missing attribute(s) ['author'] in text[209], skipping
# ERROR:Datasets:Missing attribute(s) ['author'] in text[238], skipping
# ERROR:Datasets:Missing attribute(s) ['text'] in text[243], skipping
# ERROR:Datasets:Missing attribute(s) ['author'] in text[268], skipping
# ERROR:Datasets:Missing attribute(s) ['text'] in text[272], skipping
# ERROR:Datasets:Missing attribute(s) ['text'] in text[282], skipping
# ERROR:Datasets:Missing attribute(s) ['text'] in text[289], skipping
# ERROR:Datasets:Missing attribute(s) ['author'] in text[318], skipping
# ERROR:Datasets:Missing attribute(s) ['author'] in text[380], skipping
# ERROR:Datasets:Missing attribute(s) ['text'] in text[382], skipping
# ERROR:Datasets:Missing attribute(s) ['author'] in text[414], skipping
# ERROR:Datasets:Missing attribute(s) ['text'] in text[428], skipping
# ERROR:Datasets:Missing attribute(s) ['author', 'text'] in text[439], skipping
# ERROR:Datasets:Missing attribute(s) ['text'] in text[458], skipping
# ERROR:Datasets:Missing attribute(s) ['author'] in text[467], skipping
# ERROR:Datasets:Missing attribute(s) ['text'] in text[468], skipping
# ERROR:Datasets:Missing attribute(s) ['author'] in text[470], skipping
# ERROR:Datasets:Missing attribute(s) ['author'] in text[490], skipping
# INFO:Datasets:Loaded 474 texts

# %%
len(tl.text_list)
# Out:
# 474

# %%
for i in range(3):
    idx, txt = tl.get_random_sample(80, weighted=False)
    print(tl.text_list[idx]['title'])
    print(txt)
    print()
# Out:
# Ohio Biological Survey, Bull 10, Vol. 11, No. 6
# minute to small, 0.25 to 0.4 mm. in diameter, yellow-brown and darkening, adnate
#
# A Logic Of Facts
# e wildest conjecture, unless made by a madman, there is some reason. Hypothesis
#
# Chronological Table of the Catholic Primates of Ireland
# derers of Thomas a Becket, to ingratiate himself with Henry, by a similar act of

# %%
print(tl.text_list[idx]['title'])
print(txt)
# Out:
# Chronological Table of the Catholic Primates of Ireland
# derers of Thomas a Becket, to ingratiate himself with Henry, by a similar act of

# %%
tl.tcum[:10]
# Out:
# [0.00027780643809618906,
#  0.002864678950037528,
#  0.0057174211470010965,
#  0.008127887589850542,
#  0.011424965893630309,
#  0.014922314910917838,
#  0.016222078443573592,
#  0.01635423788453016,
#  0.018469493447533413,
#  0.020126362627552116]

# %%
tl.source_highlight("Wenn wir irgendwas schreiben, daß Teil aus der Source enthält, so wie: Das ist ihr Wahlspruch, dann erfolgt ein Highlight")
# Out:
# <span style="background-color:#d4e6e1;">Wenn wir i</span><sup>[96]</sup>rgendwa<span style="background-color:#fae5d3;">s schreiben</span><sup>[61]</sup>, daß<span style="background-color:#edebd0;"> Teil aus der </span><sup>[213]</sup>Sourc<span style="background-color:#eadbd8;">e enthält, so </span><sup>[83]</sup>wie<span style="background-color:#e5e8e8;">: Das ist </span><sup>[383]</sup>ih<span style="background-color:#fae5d3;">r Wahlspruch</span><sup>[61]</sup>, dan<span style="background-color:#d4efdf;">n erfolgt e</span><sup>[39]</sup>in Highlight
# <small><p style="text-align:right;">Sources: <span style="background-color:#d4e6e1;">Justus, Freiherr von Liebig: Die organische Chemie in ihrer Anwendung auf Physiologie und Pathologie</span><sup>[96]</sup>, <span style="background-color:#fae5d3;">Hermann Grothe: Leonardo da Vinci als Ingenieur und Philosoph</span><sup>[61]</sup>, <span style="background-color:#edebd0;">Theodor Elsenhans: Psychologie und Logik</span><sup>[213]</sup>, <span style="background-color:#eadbd8;">Rudolf Wagner: Handbuch der chemischen Technologie</span><sup>[83]</sup>, <span style="background-color:#e5e8e8;">Sigmund Freud: Zur Psychopathologie des Alltagslebens</span><sup>[383]</sup>, <span style="background-color:#d4efdf;">Otto Ule: Warum und Weil. Physikalischer Teil.</span><sup>[39]</sup></p></small>

# %%
tl.source_highlight("If we write anything that contains parts of the sources, like: that is their motto, then a highlight will be applied.")
# Out:
# <span style="background-color:#e2d7d5;">If we write </span><sup>[132]</sup><span style="background-color:#ecf3cf;">anything that cont</span><sup>[374]</sup><span style="background-color:#d0ece7;">ains parts </span><sup>[376]</sup><span style="background-color:#d8daef;">of the sources, </span><sup>[417]</sup>lik<span style="background-color:#eadbd8;">e: that is the</span><sup>[3]</sup><span style="background-color:#ebdef0;">ir motto, t</span><sup>[114]</sup><span style="background-color:#e5e8e8;">hen a highl</span><sup>[31]</sup><span style="background-color:#d4e6e1;">ight will be app</span><sup>[272]</sup>lied.
# <small><p style="text-align:right;">Sources: <span style="background-color:#e2d7d5;">Mary Somerville: On the Connexion of the Physical Sciences</span><sup>[132]</sup>, <span style="background-color:#ecf3cf;">Andrew T. Still: Philosophy of Osteopathy</span><sup>[374]</sup>, <span style="background-color:#d0ece7;">Bertrand Russell: Mysticism and Logic and Other Essays</span><sup>[376]</sup>, <span style="background-color:#d8daef;">Lucien Poincare: The New Physics and Its Evolution</span><sup>[417]</sup>, <span style="background-color:#eadbd8;">Yrjö Hirn: The origins of art, a psychological & sociological inquiry</span><sup>[3]</sup>, <span style="background-color:#ebdef0;">Richard Watson: A Biblical and Theological Dictionary</span><sup>[114]</sup>, <span style="background-color:#e5e8e8;">John Ayrton Paris: Pharmacologia</span><sup>[31]</sup>, <span style="background-color:#d4e6e1;">William Garnett: Heroes of Science: Physicists</span><sup>[272]</sup></p></small>

# %%
test_text="Das ist ja mal ein Argument!"
tokenizer='word'
st = tl.tokenize(test_text, tokenizer=tokenizer)
st
# Out:
# ['Das', 'ist', 'ja', 'mal', 'ein', 'Argument', '!']

# %%
el=tl.encode(test_text, tokenizer=tokenizer)
el
# Out:
# [13393, 55978, 44676, 9149, 7440, 33507, 4266]

# %%
tl.decode(el, tokenizer=tokenizer)
# Out:
# 'Das ist ja mal ein Argument !'

# %% [markdown]
# ## Pandas and Huggingface datasets
#
# `!pip install transformer` or `conda install transformers`
# `!pip install datasets` or `conda install datasets`

# %%
sl2[1].keys()
# Out:
# dict_keys(['title', 'ebook_id', 'author', 'subtitle', 'language', 'text', 'index', 'probability_weight'])

# %%
import pandas as pd

# %%
df = pd.DataFrame(sl2)

# %%
df
# Out:
#                                                  title ebook_id  \
# 0                               First notions of logic    67017
# 1                Researches Chemical and Philosophical    66955
# 2    The origins of art, a psychological & sociolog...    66869
# 3    The Story of a Boulder; or, Gleanings from the...    66703
# 4    Astronomy and General Physics Considered with ...    66406
# ..                                                 ...      ...
# 488        Philosophy 4, A Story of Harvard University      862
# 489                                        Philoktetes     806C
# 490  Psychological Counter-current in Recent Fictio...      726
# 491                 The Philobiblon of Richard de Bury      626
# 492                           The Philosophy of Misery      444
#
#                  author                                           subtitle  \
# 0    Augustus De Morgan             (preparatory to the study of geometry)
# 1          Humphry Davy  Chiefly concerning nitrous oxide or dephlogist...
# 2             Yrjö Hirn                                                NaN
# 3      Archibald Geikie                                                NaN
# 4                   NaN                                                NaN
# ..                  ...                                                ...
# 488         Owen Wister                                                NaN
# 489           Sophocles                                                NaN
# 490                 NaN                                                NaN
# 491     Richard de Bury                                                NaN
# 492      P. J. Proudhon                                                NaN
#
#     language                                               text  index  \
# 0    English                               FIRST NOTIONS\n  ...    1.0
# 1    English                        RESEARCHES,\n           ...    2.0
# 2    English                            THE ORIGINS OF ART\n...    3.0
# 3    English                         THE STORY OF A BOULDER....    4.0
# 4    English                          BRIDGEWATER TREATISES....    NaN
# ..       ...                                                ...    ...
# 488  English  PHILOSOPHY 4\n\nA STORY OF HARVARD UNIVERSITY\...  471.0
# 489  English  SOPHOKLES\n\nPHILOKTETES\n\nTranslated by Greg...  472.0
# 490  English  A PSYCHOLOGICAL COUNTER-CURRENT IN RECENT FICT...    NaN
# 491  English  THE LOVE OF BOOKS\n\nTHE PHILOBIBLON OF RICHAR...  473.0
# 492  English  Project Gutenberg Etext of The Philosophy of M...  474.0
#
#      probability_weight illustrator editor translator author a.k.a. editors
# 0              0.000278         NaN    NaN        NaN           NaN     NaN
# 1              0.002587         NaN    NaN        NaN           NaN     NaN
# 2              0.002853         NaN    NaN        NaN           NaN     NaN
# 3              0.002410         NaN    NaN        NaN           NaN     NaN
# 4                   NaN         NaN    NaN        NaN           NaN     NaN
# ..                  ...         ...    ...        ...           ...     ...
# 488            0.000287         NaN    NaN        NaN           NaN     NaN
# 489            0.000318         NaN    NaN        NaN           NaN     NaN
# 490                 NaN         NaN    NaN        NaN           NaN     NaN
# 491            0.000630         NaN    NaN        NaN           NaN     NaN
# 492            0.003847         NaN    NaN        NaN           NaN     NaN
#
# [493 rows x 13 columns]
